# %%
import opendatasets as od

# %%
od.download('https://www.kaggle.com/datasets/rabieelkharoua/students-performance-dataset/data?select=Student_performance_data+_.csv')
# Out:
# Skipping, found downloaded files in "./students-performance-dataset" (use force=True to force download)

# %%
df=pd.read_csv('students-performance-dataset/Student_performance_data _.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
sns.boxplot(df,x='Age',y='GPA')
# Out:
# <Axes: xlabel='Age', ylabel='GPA'>

# %%
sns.boxplot(df,x='Gender',y='GPA')
# Out:
# <Axes: xlabel='Gender', ylabel='GPA'>

# %%
sns.boxplot(df,x='Ethnicity',y='GPA')
# Out:
# <Axes: xlabel='Ethnicity', ylabel='GPA'>

# %%
sns.boxplot(df,x='ParentalEducation',y='GPA')
# Out:
# <Axes: xlabel='ParentalEducation', ylabel='GPA'>

# %%
sns.boxplot(df,x='ParentalSupport',y='GPA')
# Out:
# <Axes: xlabel='ParentalSupport', ylabel='GPA'>

# %%
sns.boxplot(df,x='Tutoring',y='GPA')
# Out:
# <Axes: xlabel='Tutoring', ylabel='GPA'>

# %%
sns.boxplot(df,x='Extracurricular',y='GPA')
# Out:
# <Axes: xlabel='Extracurricular', ylabel='GPA'>

# %%
sns.boxplot(df,x='Sports',y='GPA')
# Out:
# <Axes: xlabel='Sports', ylabel='GPA'>

# %%
sns.boxplot(df,x='Music',y='GPA')
# Out:
# <Axes: xlabel='Music', ylabel='GPA'>

# %%
sns.boxplot(df,x='Volunteering',y='GPA')
# Out:
# <Axes: xlabel='Volunteering', ylabel='GPA'>

# %%
sns.boxplot(data=df, x='GradeClass', y='StudyTimeWeekly')
# Out:
# <Axes: xlabel='GradeClass', ylabel='StudyTimeWeekly'>

# %%
df.plot(x="Absences", y="GPA", kind="scatter")
# Out:
# <Axes: xlabel='Absences', ylabel='GPA'>

# %%
df.drop(columns=['StudentID','Age','Gender','Ethnicity','ParentalEducation','Sports','Volunteering','GradeClass'],inplace=True)

# %%
df.head()
# Out:
#    StudyTimeWeekly  Absences  Tutoring  ParentalSupport  Extracurricular  \
# 0        19.833723         7         1                2                0
# 1        15.408756         0         0                1                0
# 2         4.210570        26         0                2                0
# 3        10.028829        14         0                3                1
# 4         4.672495        17         1                3                0
#
#    Music       GPA
# 0      1  2.929196
# 1      0  3.042915
# 2      0  0.112602
# 3      0  2.054218
# 4      0  1.288061

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['GPA']),df['GPA'],test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = linear_model.LinearRegression()
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.9433447219775849

# %%
from sklearn.model_selection import KFold, cross_val_score
k_folds = KFold(n_splits = 10)

# %%
scores = cross_val_score(lin_reg, X_train, y_train, cv = k_folds)
scores.mean()
# Out:
# 0.943175952795624
